# %%
import pandas as pd
import plotly.graph_objects as go
from plotly.subplots import make_subplots

file_path = 'consumo mondiale.csv'
df = pd.read_csv(file_path)

traduzioni_paesi = {
    'Zambia': 'Zambia', 'Yemen': 'Yemen', 'Bangladesh': 'Bangladesh',
    'Pakistan': 'Pakistan', 'Sudafrica': 'South Africa',
    'Repubblica Centrafricana': 'Central African Republic', 'Gabon': 'Gabon',
    'Benin': 'Benin', 'Gibuti': 'Djibouti', 'Cile': 'Chile',
    'Madagascar': 'Madagascar', 'Ruanda': 'Rwanda', 'Ciad': 'Chad',
    "Stati Uniti d'America": "United States of America", 'Guinea': 'Guinea',
    'Uganda': 'Uganda', 'Namibia': 'Namibia', 'Barbados': 'Barbados',
    'Capo Verde': 'Cape Verde', 'Ghana': 'Ghana', 'Mali': 'Mali',
    'Sao Tome e Principe': 'Sao Tome and Principe',
    'Repubblica Dominicana': 'Dominican Republic',
    'Mauritania': 'Mauritania', 'Emirati Arabi Uniti': 'United Arab Emirates',
    'Giamaica': 'Jamaica', 'Afghanistan': 'Afghanistan', 'Senegal': 'Senegal',
    'Greenland': 'Greenland', 'Trinidad e Tobago': 'Trinidad and Tobago',
    'Nepal': 'Nepal', 'Nauru': 'Nauru', 'Porto Rico': 'Puerto Rico',
    'Tuvalu': 'Tuvalu', 'Samoa': 'Samoa', 'Angola': 'Angola',
    'Grecia': 'Greece', 'Sudan del sud': 'South Sudan', 'Georgia': 'Georgia',
    'Samoa Americane': 'American Samoa',
    'Guinea Equatoriale': 'Equatorial Guinea', 'Guam': 'Guam',
    'Tagikistan': 'Tajikistan', 'Albania': 'Albania', 'Niue': 'Niue',
    'Repubblica Ceca': 'Czechia', 'Polonia': 'Poland',
    'Kirghizistan': 'Kyrgyzstan', 'Slovenia': 'Slovenia',
    'Unione delle Comore': 'Comoros', 'Finlandia': 'Finland',
    'Islanda': 'Iceland', 'Lussemburgo': 'Luxembourg', 'Italia': 'Italy',
    'Peru': 'Peru', 'Kenya': 'Kenya', 'Norvegia': 'Norway',
    'Uzbekistan': 'Uzbekistan', 'El Salvador': 'El Salvador',
    'Bulgaria': 'Bulgaria', 'Mozambico': 'Mozambique',
    'Nicaragua': 'Nicaragua', 'Lituania': 'Lithuania',
    'Saint Kitts e Nevis': 'Saint Kitts and Nevis',
    'Isole Vergini Americane ': 'United States Virgin Islands',
    'Repubblica di Corea': 'South Korea', 'Portogallo': 'Portugal',
    'Papua Nuova Guinea': 'Papua New Guinea', 'Regno Unito': 'United Kingdom',
    'Vanuatu': 'Vanuatu', 'Azerbaigian': 'Azerbaijan', 'Uruguay': 'Uruguay',
    'Mongolia': 'Mongolia', 'Croazia': 'Croatia', 'Macedonia': 'North Macedonia',
    'Svizzera': 'Switzerland', 'Cina': 'China', 'Taiwan': 'Taiwan',
    'Cambogia': 'Cambodia', 'Francia': 'France', 'Serbia': 'Serbia',
    'Repubblica Unita di Tanzania': 'Tanzania', 'Bielorussa': 'Belarus',
    'Myanmar': 'Myanmar', 'Timor Est': 'East Timor',
    'Sierra Leone': 'Sierra Leone', 'Estonia': 'Estonia',
    'Kiribati': 'Kiribati', 'Micronesia (Stati Federati di)': 'Micronesia',
    'Montenegro': 'Montenegro', 'Lesotho': 'Lesotho', 'Zimbabwe': 'Zimbabwe',
    'Belize': 'Belize', 'Camerun': 'Cameroon', 'Slovacchia': 'Slovakia',
    'Grenada': 'Grenada', 'Malesia': 'Malaysia', 'Bermuda': 'Bermuda',
    'Saint Lucia': 'Saint Lucia', 'Lettonia': 'Latvia',
    'Isole Marianne Settentrionali': 'Northern Mariana Islands',
    'Tonga': 'Tonga', 'Gambia': 'Gambia', 'Brasile': 'Brazil',
    'Liberia': 'Liberia', 'Armenia': 'Armenia',
    'Federazione Russa': 'Russia', 'Algeria': 'Algeria',
    'Repubblica Popolare Democratica di Corea': 'North Korea',
    'Sudan': 'Sudan', 'Iraq': 'Iraq', 'Nigeria': 'Nigeria',
    'Ucraina': 'Ukraine', 'Indonesia': 'Indonesia', 'San Marino': 'San Marino',
    'Monaco': 'Monaco', 'Togo': 'Togo', 'Brunei': 'Brunei',
    'Filippine': 'Philippines', 'Guatemala': 'Guatemala', 'Palau': 'Palau',
    'Marocco': 'Morocco', 'Vietnam': 'Vietnam', 'Panama': 'Panama',
    'Tokelau': 'Tokelau', 'Andorra': 'Andorra', 'Giappone': 'Japan',
    'Paraguay': 'Paraguay', 'Arabia Saudita': 'Saudi Arabia',
    'Danimarca': 'Denmark', 'Australia': 'Australia',
    'Isole Marshall': 'Marshall Islands',
    'Antigua and Barbuda': 'Antigua and Barbuda', 'Bahrain': 'Bahrain',
    'Irlanda': 'Ireland', 'Nuova Zelanda': 'New Zealand', 'Austria': 'Austria',
    'Isole Salomone': 'Solomon Islands', 'Malta': 'Malta', 'Belgio': 'Belgium',
    'Spagna': 'Spain', 'Giordania': 'Jordan', 'Cuba': 'Cuba',
    'Isole Cook': 'Cook Islands', 'Guyana': 'Guyana',
    'Kazakistan': 'Kazakhstan',
    'Saint Vincent e Grenadine': 'Saint Vincent and the Grenadines',
    'Turkmenistan': 'Turkmenistan', 'Palestina': 'Palestine',
    'Bolivia (Stato Plurinazionale della)': 'Bolivia',
    'Bosnia ed Erzegovina': 'Bosnia and Herzegovina',
    'Repubblica Araba Siriana': 'Syria', 'Ungheria': 'Hungary',
    'Romania': 'Romania', 'Turchia': 'Turkey', 'Maldive': 'Maldives',
    'Argentina': 'Argentina', 'Germania': 'Germany', 'Burundi': 'Burundi',
    'Repubblica di Moldavia': 'Moldova', 'Bhutan': 'Bhutan',
    'Israele': 'Israel', 'Singapore': 'Singapore',
    'Paesi Bassi': 'Netherlands', 'Cipro': 'Cyprus',
    'Tailandia': 'Thailand', 'Svezia': 'Sweden', 'Figi': 'Fiji',
    'India': 'India', 'Etiopia': 'Ethiopia', 'Canada': 'Canada',
    'Repubblica Democratica Popolare del Laos': 'Laos',
    'Mauritius': 'Mauritius', 'Congo': 'Republic of Congo',
    'Colombia': 'Colombia', 'Honduras': 'Honduras', 'Sri Lanka': 'Sri Lanka',
    'Venezuela (Repubblica Bolivariana del)': 'Venezuela',
    'Repubblica Democratica del Congo': 'Democratic Republic of the Congo',
    'Eritrea': 'Eritrea', 'Malawi': 'Malawi', 'Le Bahamas': 'Bahamas',
    'Somalia': 'Somalia', 'Dominica': 'Dominica', 'Seychelles': 'Seychelles',
    'Botswana': 'Botswana', 'Swaziland': 'Eswatini',
    'Burkina Faso': 'Burkina Faso', "Costa d'Avorio": "Ivory Coast",
    'Egitto': 'Egypt', 'Haiti': 'Haiti', 'Guinea-Bissau': 'Guinea-Bissau',
    'Suriname': 'Suriname', 'Niger': 'Niger', 'Ecuador': 'Ecuador',
    'Costa Rica': 'Costa Rica', 'Messico': 'Mexico',
    "Iran (Repubblica Islamica dell')": 'Iran', 'Libano': 'Lebanon',
    'Libia': 'Libya', 'Qatar': 'Qatar', 'Kuwait': 'Kuwait', 'Oman': 'Oman',
    'Tunisia': 'Tunisia',
}

df['location_eng'] = df['location_name'].map(lambda x: traduzioni_paesi.get(x, x))

COLORSCALE = [
    [0.000, '#f7fbff'],
    [0.060, '#deebf7'],
    [0.140, '#c6dbef'],
    [0.260, '#9ecae1'],
    [0.400, '#6baed6'],
    [0.520, '#4292c6'],
    [0.620, "#3481c4"],
    [0.720, "#9c7be8"],
    [0.820, "#8363cf"],
    [0.900, "#6d4cba"],
    [0.960, "#5a3aa5"],
    [1.000, "#46298a"],
]

SCALE_MIN = 0.0
SCALE_MAX = 2.5

COLORBAR_TICKS  = [0, 0.5, 1.0, 1.5, 2.0, 2.5]
COLORBAR_LABELS = ['0%', '0.5%', '1%', '1.5%', '2%', '≥2.5%']

years   = sorted(df['year'].unique())
df_1990 = df[df['year'] == 1990].copy()

GEO_COMMON = dict(
    showframe=False,
    showcoastlines=True,
    coastlinecolor='white',
    coastlinewidth=0.5,
    showland=True,
    landcolor='#d9d9d9',
    showocean=True,
    oceancolor='#f0f4f8',
    showlakes=False,
    projection_type='natural earth',
    bgcolor='rgba(0,0,0,0)',
)

fig = make_subplots(
    rows=1, cols=2,
    column_widths=[0.5, 0.5],
    specs=[[{'type': 'choropleth'}, {'type': 'choropleth'}]],
    horizontal_spacing=0.01,
    subplot_titles=['1990', str(years[0])],
)

COLORBAR_CFG = dict(
    thickness=16,
    len=0.60,
    y=0.45,
    x=1.01,
    outlinewidth=0,
    tickvals=COLORBAR_TICKS,
    ticktext=COLORBAR_LABELS,
    tickfont=dict(size=11),
    title=dict(text='% pop.', side='right', font=dict(size=11)),
)

def make_choropleth(df_sub, show_scale):
    return go.Choropleth(
        locations=df_sub['location_eng'],
        locationmode='country names',
        z=df_sub['val'],
        zmin=SCALE_MIN,
        zmax=SCALE_MAX,
        colorscale=COLORSCALE,
        showscale=show_scale,
        colorbar=COLORBAR_CFG if show_scale else None,
        marker_line_color='white',
        marker_line_width=0.4,
        customdata=list(zip(
            df_sub['location_name'],
            df_sub['val'].round(2),
            df_sub['lower'].round(2),
            df_sub['upper'].round(2),
        )),
        hovertemplate=(
            '<b>%{customdata[0]}</b><br>'
            'SEV: %{customdata[1]:.2f}%<br>'
            'Intervallo: %{customdata[2]:.2f}% – %{customdata[3]:.2f}%'
            '<extra></extra>'
        ),
    )

fig.add_trace(make_choropleth(df_1990, show_scale=False), row=1, col=1)

df_yr0 = df[df['year'] == years[0]].copy()
fig.add_trace(make_choropleth(df_yr0, show_scale=True), row=1, col=2)

frames = []
for yr in years:
    df_yr = df[df['year'] == yr].copy()
    ch = make_choropleth(df_yr, show_scale=True)
    frame = go.Frame(
        name=str(yr),
        data=[ch],
        traces=[1],
        layout=go.Layout(
            annotations=[
                dict(text='1990', x=0.23, y=1.05, xref='paper', yref='paper',
                     showarrow=False, font=dict(size=16, color='#333')),
                dict(text=str(yr), x=0.77, y=1.05, xref='paper', yref='paper',
                     showarrow=False, font=dict(size=16, color='#333')),
            ]
        )
    )
    frames.append(frame)

fig.frames = frames

sliders = [dict(
    active=0,
    currentvalue=dict(prefix='Anno: ', visible=True, xanchor='center',
                      font=dict(size=13, color='#555')),
    pad=dict(b=10, t=10),
    len=0.88,
    x=0.06,
    y=0,
    steps=[
        dict(
            args=[[str(yr)],
                  dict(frame=dict(duration=300, redraw=True),
                       mode='immediate',
                       transition=dict(duration=150))],
            label=str(yr),
            method='animate',
        )
        for yr in years
    ],
)]

updatemenus = [dict(
    type='buttons',
    showactive=False,
    x=0.0025, y=-0.04,
    xanchor='left', yanchor='top',
    buttons=[
        dict(label='▶  Play', method='animate',
             args=[None, dict(frame=dict(duration=400, redraw=True),
                              fromcurrent=True,
                              transition=dict(duration=133))]),
        dict(label='⏸  Pausa', method='animate',
             args=[[None], dict(frame=dict(duration=0, redraw=False),
                                mode='immediate',
                                transition=dict(duration=0))]),
    ],
)]

fig.update_layout(
    title=dict(
        x=0.5, xanchor='center',
        font=dict(size=17, color='#222'),
    ),
    annotations=[
        dict(text='1990', x=0.23, y=1.05, xref='paper', yref='paper',
             showarrow=False, font=dict(size=16, color='#333')),
        dict(text=str(years[0]), x=0.77, y=1.05, xref='paper', yref='paper',
             showarrow=False, font=dict(size=16, color='#333')),
    ],
    geo=dict(**GEO_COMMON),
    geo2=dict(**GEO_COMMON),
    paper_bgcolor='white',
    plot_bgcolor='white',
    height=480,
    margin=dict(l=0, r=65, t=70, b=80),
    sliders=sliders,
    updatemenus=updatemenus,
)

fig.show()
